# %%
from bertviz.attention_map import AttentionMapData, show
import torch
from mptb import BertModel, Config
from mptb.tokenization_sentencepiece import FullTokenizer
from IPython.display import display

tokenizer = FullTokenizer('data/bert-wiki-ja/wiki-ja.model', 'data/bert-wiki-ja/wiki-ja.vocab')
model_cfg = Config.from_json('config/bert_base.json', len(tokenizer), 512)
model = BertModel(model_cfg)
model.load_state_dict(torch.load('data/bert-wiki-ja/bert-wiki-ja.pt', map_location='cpu'))
# Out:
# Loaded a trained SentencePiece model.

# %%
# %%javascript
# require.config({
#   paths: {
#       d3: '//cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min'
#   }
# });

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
def call_html():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              "d3": "https://cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min",
              jquery: '//ajax.googleapis.com/ajax/libs/jquery/3.3.1/jquery.min',
            },
          });
        </script>
        '''))

# %%
sentence_a = "吾輩は猫である"
sentence_b = "名前はまだ無い"
map_data = AttentionMapData(model, tokenizer)
tokens_a, tokens_b, atts = map_data.get_data(sentence_a, sentence_b)
call_html()
show(tokens_a, tokens_b, atts)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               "d3": "https://cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min",
#               jquery: '//ajax.googleapis.com/ajax/libs/jquery/3.3.1/jquery.min',
#             },
#           });
#         </script>
#   <span style="user-select:none">
#     Attention: <select id="attType">
#       <option value="all">All</option>
#       <option value="aa">Sentence A -> Sentence A</option>
#       <option value="bb">Sentence B -> Sentence B</option>
#       <option value="ab">Sentence A -> Sentence B</option>
#       <option value="ba">Sentence B -> Sentence A</option>
#     </select>
#   </span>
#   <div id='vis'></div>
